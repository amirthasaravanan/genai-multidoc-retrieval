# %%
from helper import get_openai_api_key
OPENAI_API_KEY = get_openai_api_key()

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
urls = [
    "https://openreview.net/pdf?id=jHDZEUgS4r",
    "https://openreview.net/pdf?id=CCSPm6V5EF",
    "https://openreview.net/pdf?id=krGpQzo8Mz",
    "https://openreview.net/pdf?id=kMuQBgPIdg",
    "https://openreview.net/pdf?id=xuY33XhEGR"
    
]

papers = [
    "MEDAGENTGYM.pdf",
    "WEBDEVJUDGE.pdf",
    "LATENT_SPEECH_TEXT_TRANSFORMER.pdf",
    "GENERATIVE_AUTO_BIDDING.pdf",
    "CLIMODE.pdf"
]

# %%
from utils import get_doc_tools
from pathlib import Path

paper_to_tools_dict = {}
for paper in papers:
    print(f"Getting tools for paper: {paper}")
    vector_tool, summary_tool = get_doc_tools(paper, Path(paper).stem)
    paper_to_tools_dict[paper] = [vector_tool, summary_tool]
# Out:
# Getting tools for paper: MEDAGENTGYM.pdf
# Getting tools for paper: WEBDEVJUDGE.pdf
# Getting tools for paper: LATENT_SPEECH_TEXT_TRANSFORMER.pdf
# Getting tools for paper: GENERATIVE_AUTO_BIDDING.pdf
# Getting tools for paper: CLIMODE.pdf

# %%
initial_tools = [t for paper in papers for t in paper_to_tools_dict[paper]]

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo")

# %%
len(initial_tools)
# Out:
# 10

# %%
from llama_index.core.agent import FunctionCallingAgentWorker
from llama_index.core.agent import AgentRunner

agent_worker = FunctionCallingAgentWorker.from_tools(
    initial_tools, 
    llm=llm, 
    verbose=True
)
agent = AgentRunner(agent_worker)

# %%
response = agent.query(
    "What is MedAgentGym?"
    "What is auto-bidding in online advertising?"
    "What problem does ClimODE solve?"
    "Why are speech-text models computationally expensive?"
    "Why was WEBDEVJUDGE introduced?"
    
)
# Out:
# Added user message to memory: What is MedAgentGym?What is auto-bidding in online advertising?What problem does ClimODE solve?Why are speech-text models computationally expensive?Why was WEBDEVJUDGE introduced?Why was WEBDEVJUDGE introduced?
# === Calling Function ===
# Calling function: summary_tool_MEDAGENTGYM with args: {"input": "MedAgentGym"}
# === Function Output ===
# MedAgentGym is a scalable and interactive training environment designed to enhance coding-based biomedical reasoning capabilities in large language model (LLM) agents. It comprises a comprehensive suite of tasks across various biomedical scenarios, providing detailed specifications, interactive feedback mechanisms, and verifiable ground truth annotations. Through extensive benchmarking, MedAgentGym demonstrates significant performance disparities in biomedical data science between commercial and open-source LLMs. Leveraging efficient trajectory sampling and reinforcement learning, MedAgentGym facilitates effective training for developing LLM-based coding assistants in advanced biomedical data science.
# === Calling Function ===
# Calling function: summary_tool_GENERATIVE_AUTO_BIDDING with args: {"input": "Auto-bidding in online advertising"}
# === Function Output ===
# Auto-bidding in online advertising involves utilizing automated systems to adjust bids for ad placements in real-time auctions based on factors like user data, ad performance, and budget constraints. These systems use algorithms to optimize bidding strategies, aiming to maximize return on investment by efficiently allocating resources and targeting the right audience. By automatically adjusting bids and targeting parameters, auto-bidding systems help advertisers scale their campaigns, improve ad performance, and achieve their advertising goals more effectively than manual bidding processes.
# === Calling Function ===
# Calling function: summary_tool_CLIMODE with args: {"input": "Problem solved by ClimODE"}
# === Function Output ===
# ClimODE effectively solves the problem of forecasting both regional weather dynamics and monthly climate conditions.
# === Calling Function ===
# Calling function: summary_tool_LATENT_SPEECH_TEXT_TRANSFORMER with args: {"input": "Reasons for computational expense of speech-text models"}
# === Function Output ===
# The computational expense of speech-text models is primarily due to factors such as the longer token sequences in speech compared to text, the need for alignment between speech and text data, dynamic generation of interleaved sequences during training, utilization of specialized tokens to differentiate between speech and text modalities, and the implementation of complex encoder-decoder architectures with attention mechanisms. Additionally, the training process involves optimization with specific optimizers like AdamW, learning rate scheduling, warmup periods, and gradient clipping. The use of multiple GPUs, mixed-precision training, and model parallelism further contribute to the computational cost.
# === Calling Function ===
# Calling function: summary_tool_WEBDEVJUDGE with args: {"input": "Reason for introducing WEBDEVJUDGE"}
# === Function Output ===
# The reason for introducing WEBDEVJUDGE was to provide a systematic benchmark for assessing automated evaluators in complex scenarios, particularly focusing on web development tasks. This benchmark aimed to evaluate the performance of LLM-as-a-judge approaches, establish feasible assessment standards, and guide future research towards developing more reliable and capable automated evaluators for challenging real-world problems in the web development domain.
# === LLM Response ===
# - **MedAgentGym**: MedAgentGym is a scalable and interactive training environment designed to enhance coding-based biomedical reasoning capabilities in large language model (LLM) agents. It comprises a comprehensive suite of tasks across various biomedical scenarios, providing detailed specifications, interactive feedback mechanisms, and verifiable ground truth annotations. Through extensive benchmarking, MedAgentGym demonstrates significant performance disparities in biomedical data science between commercial and open-source LLMs. Leveraging efficient trajectory sampling and reinforcement learning, MedAgentGym facilitates effective training for developing LLM-based coding assistants in advanced biomedical data science.
#
# - **Auto-bidding in Online Advertising**: Auto-bidding in online advertising involves utilizing automated systems to adjust bids for ad placements in real-time auctions based on factors like user data, ad performance, and budget constraints. These systems use algorithms to optimize bidding strategies, aiming to maximize return on investment by efficiently allocating resources and targeting the right audience. By automatically adjusting bids and targeting parameters, auto-bidding systems help advertisers scale their campaigns, improve ad performance, and achieve their advertising goals more effectively than manual bidding processes.
#
# - **ClimODE**: ClimODE effectively solves the problem of forecasting both regional weather dynamics and monthly climate conditions.
#
# - **Computational Expense of Speech-Text Models**: The computational expense of speech-text models is primarily due to factors such as the longer token sequences in speech compared to text, the need for alignment between speech and text data, dynamic generation of interleaved sequences during training, utilization of specialized tokens to differentiate between speech and text modalities, and the implementation of complex encoder-decoder architectures with attention mechanisms. Additionally, the training process involves optimization with specific optimizers like AdamW, learning rate scheduling, warmup periods, and gradient clipping. The use of multiple GPUs, mixed-precision training, and model parallelism further contribute to the computational cost.
#
# - **WEBDEVJUDGE**: The reason for introducing WEBDEVJUDGE was to provide a systematic benchmark for assessing automated evaluators in complex scenarios, particularly focusing on web development tasks. This benchmark aimed to evaluate the performance of LLM-as-a-judge approaches, establish feasible assessment standards, and guide future research towards developing more reliable and capable automated evaluators for challenging real-world problems in the web development domain.

# %%
response = agent.query("Give me a summary of all the 5 documents")
print(str(response))
# Out:
# Added user message to memory: Give me a summary of all the 5 documents
# === Calling Function ===
# Calling function: summary_tool_MEDAGENTGYM with args: {"input": "Summary of the document"}
# === Function Output ===
# The document discusses the development and evaluation of MedAgentGym, an interactive training environment designed to enhance coding-based biomedical reasoning capabilities in large language model (LLM) agents. It comprises a comprehensive dataset with various tasks from real-world biomedical scenarios, providing detailed task specifications, interactive feedback mechanisms, and verifiable ground truth annotations. The document highlights the performance disparities between commercial and open-source LLMs in biomedical data science tasks, emphasizing the need for privacy-preserving, affordable LLM agents. It explores the training of LLM agents for code-centric biomedical reasoning, showcasing the effectiveness of different fine-tuning strategies and reinforcement learning methods. Additionally, the document addresses challenges in generalizing across specialized biomedical contexts, the impact of interactive coding mechanisms on model performance, and the importance of ethical usage and collaboration with healthcare professionals. Recommendations are provided for optimizing the use of MedAgentGym in low-resource settings, focusing on agentic fine-tuning, verifier-gated inference, and specializing in specific biomedical data science tasks.
# === Calling Function ===
# Calling function: summary_tool_WEBDEVJUDGE with args: {"input": "Summary of the document"}
# === Function Output ===
# The document introduces a benchmark called WEBDEVJUDGE for evaluating large language models (LLMs) as judges in web development tasks. It focuses on assessing LLM performance in dynamic and interactive environments, emphasizing continuous interaction and real-time assessment. The benchmark involves human preference labels over paired web implementations, annotated with structured rubrics for high-quality ground truth. It highlights a significant performance gap between LLM judges and human experts, pointing out limitations in recognizing functional equivalence, verifying task feasibility, and mitigating bias. The study provides insights for developing more reliable automated evaluators for complex scenarios in web development. Additionally, the document discusses the challenges in achieving human-level reliability in web development evaluation tasks, emphasizing the importance of recognizing functional equivalence and the need for a balanced approach combining code-aware reasoning and grounded verification for effective evaluation.
# === Calling Function ===
# Calling function: summary_tool_LATENT_SPEECH_TEXT_TRANSFORMER with args: {"input": "Summary of the document"}
# === Function Output ===
# The document introduces the Latent Speech-Text Transformer (LST) model, which aligns speech and text data through various patching strategies to improve efficiency and performance in speech understanding and generation tasks. By aggregating speech tokens into latent speech patches and utilizing different patching methods, such as Curriculum Patching, the LST model consistently enhances accuracy and reduces the performance gap between speech and text across benchmarks. It focuses on improving computational efficiency, reducing autoregressive sequence length, and lowering inference costs without compromising quality. The document also discusses the benefits of scaling the LST model from 1B to 7B parameters, showcasing improved sample efficiency and more favorable compute-optimal scaling behavior for spoken language modeling.
# === Calling Function ===
# Calling function: summary_tool_GENERATIVE_AUTO_BIDDING with args: {"input": "Summary of the document"}
# === Function Output ===
# The document discusses a novel method called AIGB-Pearl that enhances generative auto-bidding by integrating offline reward evaluation and policy search. It addresses the limitations of existing AI-generated bidding methods by proposing a trajectory evaluator to assess generation quality and a KL-Lipschitz-constrained score-maximization scheme for safe exploration beyond the offline dataset. The method aims to improve performance and generalization in auto-bidding by continuously enhancing generation quality through exploration. The document outlines the problem statement, offline RL methods, and generative auto-bidding methods, highlighting the challenges and solutions in the field of auto-bidding for online advertising. The AIGB-Pearl algorithm integrates reinforcement learning into an auto-bidding planner training process, focusing on trajectory evaluation, planner optimization, Lipschitz constraints, and reliable trajectory generation. The algorithm aims to improve overall performance metrics like GMV, BuyCnt, and ROI, demonstrating better generalization ability in real-world experiments.
# === Calling Function ===
# Calling function: summary_tool_CLIMODE with args: {"input": "Summary of the document"}
# === Function Output ===
# The document introduces CLIMODE, a novel climate and weather forecasting model that combines physics-informed neural ODEs to address the limitations of traditional numerical simulations and data-driven models. CLIMODE excels in global and regional weather forecasting, incorporating components like attention convolutional networks, spatiotemporal embeddings, and probabilistic emission models for uncertainty quantification. It outperforms existing data-driven methods with a smaller parameterization, providing state-of-the-art predictive capabilities for various meteorological variables. The model's continuous-time PDE framework grounded in physics allows for efficient training from scratch and comes with an open-source PyTorch implementation. While acknowledging limitations in predicting weather patterns amidst climate changes, the document emphasizes the importance of open data sharing, computational resources, and future research directions in climate and weather modeling.
# === LLM Response ===
# Here are the summaries of the 5 documents:
#
# 1. **MedAgentGym**: The document discusses the development and evaluation of MedAgentGym, an interactive training environment designed to enhance coding-based biomedical reasoning capabilities in large language model (LLM) agents. It emphasizes the disparities in performance between commercial and open-source LLMs in biomedical data science tasks and explores training strategies for code-centric biomedical reasoning.
#
# 2. **WEBDEVJUDGE**: Introduces a benchmark called WEBDEVJUDGE for evaluating large language models (LLMs) as judges in web development tasks. It focuses on assessing LLM performance in dynamic and interactive environments, highlighting the performance gap between LLM judges and human experts in web development evaluation tasks.
#
# 3. **Latent Speech-Text Transformer (LST)**: Introduces the LST model, aligning speech and text data through patching strategies to improve efficiency and performance in speech understanding and generation tasks. The model consistently enhances accuracy and reduces the performance gap between speech and text across benchmarks.
#
# 4. **Generative Auto-Bidding (AIGB-Pearl)**: Discusses a method that enhances generative auto-bidding by integrating offline reward evaluation and policy search. The AIGB-Pearl algorithm aims to improve performance and generalization in auto-bidding by continuously enhancing generation quality through exploration.
#
# 5. **CLIMODE**: Introduces a climate and weather forecasting model that combines physics-informed neural ODEs to address the limitations of traditional numerical simulations and data-driven models. CLIMODE excels in global and regional weather forecasting, providing state-of-the-art predictive capabilities for various meteorological variables.
# assistant: Here are the summaries of the 5 documents:
#
# 1. **MedAgentGym**: The document discusses the development and evaluation of MedAgentGym, an interactive training environment designed to enhance coding-based biomedical reasoning capabilities in large language model (LLM) agents. It emphasizes the disparities in performance between commercial and open-source LLMs in biomedical data science tasks and explores training strategies for code-centric biomedical reasoning.
#
# 2. **WEBDEVJUDGE**: Introduces a benchmark called WEBDEVJUDGE for evaluating large language models (LLMs) as judges in web development tasks. It focuses on assessing LLM performance in dynamic and interactive environments, highlighting the performance gap between LLM judges and human experts in web development evaluation tasks.
#
# 3. **Latent Speech-Text Transformer (LST)**: Introduces the LST model, aligning speech and text data through patching strategies to improve efficiency and performance in speech understanding and generation tasks. The model consistently enhances accuracy and reduces the performance gap between speech and text across benchmarks.
#
# 4. **Generative Auto-Bidding (AIGB-Pearl)**: Discusses a method that enhances generative auto-bidding by integrating offline reward evaluation and policy search. The AIGB-Pearl algorithm aims to improve performance and generalization in auto-bidding by continuously enhancing generation quality through exploration.
#
# 5. **CLIMODE**: Introduces a climate and weather forecasting model that combines physics-informed neural ODEs to address the limitations of traditional numerical simulations and data-driven models. CLIMODE excels in global and regional weather forecasting, providing state-of-the-art predictive capabilities for various meteorological variables.
